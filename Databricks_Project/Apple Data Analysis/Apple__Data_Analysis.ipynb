# %%
# %run "./reader_factory"

# %%
class Workflow:
  
  def __init__(self):
    pass
    
  def runner(self):
     # Use the get_data_frame function from reader_factory
     transactioninputDf = get_data_frame(
         "/Volumes/workspace/default/megamart/Transaction_Updated.csv"
     )
     
     display(transactioninputDf)

workflow = Workflow()
workflow.runner()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Spark DataFrames").getOrCreate()
input_df = spark.read.csv('/Volumes/workspace/default/apple_store/Transaction_Updated.csv', header=True)

input_df.display()
